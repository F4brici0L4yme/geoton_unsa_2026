# %% [markdown]
# # 📊 Title
#
# **Objective:**
# **Data Source:**
# **Output:**

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# from dbfread import DBF  # descomentar si usas .dbf

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ### Paths

# %%
# Entradas
PATH_RAW_X = '../../data/external/archivo_X.dbf'

# Salidas
PATH_OUT_X    = '../../data/cleaned/salida_X.csv'

# %% [markdown]
# ### Data Loading

# %%
# --- Opción A: CSV ---
# df_a = pd.read_csv(PATH_RAW_A, encoding='utf-8')

# --- Opción B: DBF ---
# from dbfread import DBF
# df_a = pd.DataFrame(iter(DBF(PATH_RAW_A, encoding='cp1252')))
# df_b = pd.DataFrame(iter(DBF(PATH_RAW_B, encoding='utf-8')))

# --- Opción C: Excel ---
# df_a = pd.read_excel(PATH_RAW_A, sheet_name=0)

# %% [markdown]
# ### Data Inspection

# %%
#df_a.describe(include='all')

# %%
# Columnas disponibles
# print('Columnas df_a:', list(df_a.columns))
# print('Columnas df_b:', list(df_b.columns))

# Nulos por columna
# print('Nulos df_a:')
# print(df_a.isnull().sum())

# Duplicados
# print('Duplicados df_a:', df_a.duplicated().sum())
# print('Duplicados df_b:', df_b.duplicated().sum())

# %% [markdown]
# ### Filter

# %%
# FILTRO = '04'  # ajustar
# df_a_filtrado = df_a[df_a['CODGEO'].str.startswith(FILTRO)]
# df_b_filtrado = df_b[df_b['CODGEO'].str.startswith(FILTRO)]

# %% [markdown]
# ### Output

# %%
# Guardar por separado
df_a_filtrado.to_csv(PATH_OUT_A, index=False)
df_b_filtrado.to_csv(PATH_OUT_B, index=False)

# Concatenar y guardar combinado
df_combined = pd.concat([df_a_filtrado, df_b_filtrado], ignore_index=True)
df_combined.to_csv(PATH_OUT_FULL, index=False)

print(f'Exportado: {PATH_OUT_A} ({df_a_filtrado.shape[0]} filas)')
print(f'Exportado: {PATH_OUT_B} ({df_b_filtrado.shape[0]} filas)')
print(f'Exportado: {PATH_OUT_FULL} ({df_combined.shape[0]} filas totales)')
